# %%
# export
# yet to handle logic for that

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os, PIL, mimetypes
from pathlib import Path

# %%
os.path.exists('./imagenette-160')
# Out:
# True

# %%
path = Path('./imagenette-160')

# %%
[path for path in path.iterdir() if path.is_dir()]
# Out:
# [PosixPath('imagenette-160/train'), PosixPath('imagenette-160/val')]

# %%
Path.ls = lambda x: list(x.iterdir())

# %%
path.ls()
# Out:
# [PosixPath('imagenette-160/.DS_Store'),
#  PosixPath('imagenette-160/train'),
#  PosixPath('imagenette-160/val')]

# %%
(path/'val/').ls()
# Out:
# [PosixPath('imagenette-160/val/n03394916'),
#  PosixPath('imagenette-160/val/n03417042'),
#  PosixPath('imagenette-160/val/n03445777'),
#  PosixPath('imagenette-160/val/n02102040'),
#  PosixPath('imagenette-160/val/n03425413'),
#  PosixPath('imagenette-160/val/n03888257'),
#  PosixPath('imagenette-160/val/n03028079'),
#  PosixPath('imagenette-160/val/n03000684'),
#  PosixPath('imagenette-160/val/n01440764'),
#  PosixPath('imagenette-160/val/n02979186')]

# %%
path_image_dir = (path/'val/').ls()[0]

# %%
path_image_dir
# Out:
# PosixPath('imagenette-160/val/n03394916')

# %%
path_image = path_image_dir.ls()[0]

# %%
path_image
# Out:
# PosixPath('imagenette-160/val/n03394916/ILSVRC2012_val_00046669.JPEG')

# %%
img = PIL.Image.open(path_image)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=231x160 at 0x120E842B0>

# %%
import numpy as np
imga = np.array(img)
imga.shape
# Out:
# (160, 231, 3)

# %%
imga[:10,:10,0]
# Out:
# array([[255, 250, 255, 251, 244, 255, 255, 255, 255, 255],
#        [255, 242, 251, 253, 255, 255, 243, 251, 255, 255],
#        [255, 252, 255, 254, 255, 255, 248, 255, 255, 255],
#        [250, 255, 255, 251, 255, 255, 252, 255, 254, 254],
#        [253, 253, 247, 254, 255, 255, 251, 243, 255, 255],
#        [255, 251, 248, 255, 255, 247, 255, 255, 255, 255],
#        [255, 255, 255, 255, 243, 248, 255, 213, 227, 227],
#        [245, 255, 255, 255, 249, 255, 218,  57,  51,  51],
#        [255, 255, 253, 255, 255, 254, 226,  51, 142, 144],
#        [255, 255, 253, 255, 255, 254, 226,  51, 145, 146]], dtype=uint8)

# %%
image_extensions = set(k for k,v in mimetypes.types_map.items() if(v.startswith('image/')))

# %%
image_extensions
# Out:
# {'.3ds',
#  '.bmp',
#  '.btif',
#  '.cgm',
#  '.cmx',
#  '.djv',
#  '.djvu',
#  '.dwg',
#  '.dxf',
#  '.fbs',
#  '.fh',
#  '.fh4',
#  '.fh5',
#  '.fh7',
#  '.fhc',
#  '.fpx',
#  '.fst',
#  '.g3',
#  '.gif',
#  '.ico',
#  '.ief',
#  '.jp2',
#  '.jpe',
#  '.jpeg',
#  '.jpg',
#  '.ktx',
#  '.mac',
#  '.mdi',
#  '.mmr',
#  '.npx',
#  '.pbm',
#  '.pct',
#  '.pcx',
#  '.pgm',
#  '.pic',
#  '.pict',
#  '.png',
#  '.pnm',
#  '.pnt',
#  '.pntg',
#  '.ppm',
#  '.psd',
#  '.qti',
#  '.qtif',
#  '.ras',
#  '.rgb',
#  '.rlc',
#  '.sgi',
#  '.sid',
#  '.svg',
#  '.svgz',
#  '.tga',
#  '.tif',
#  '.tiff',
#  '.uvg',
#  '.uvi',
#  '.uvvg',
#  '.uvvi',
#  '.wbmp',
#  '.wdp',
#  '.webp',
#  '.xbm',
#  '.xif',
#  '.xpm',
#  '.xwd'}

# %%
' '.join(image_extensions)
# Out:
# '.g3 .ief .pic .dxf .npx .jp2 .xpm .sid .pntg .sgi .png .wbmp .fbs .ras .uvvg .gif .xwd .mmr .wdp .uvg .djvu .psd .btif .jpg .ktx .pcx .fhc .mdi .fh7 .xif .pnt .fh5 .djv .cmx .pbm .pct .qti .svg .cgm .xbm .ico .uvi .svgz .ppm .jpe .dwg .fh .tga .pgm .fh4 .pnm .rgb .fpx .jpeg .rlc .pict .tiff .bmp .3ds .fst .tif .webp .uvvi .mac .qtif'

# %%
def setify(o): return o if isinstance(o, set) else set(list(o))

# %%
setify('aa') == {'aa'}
# Out:
# False

# %%
def listify(p=None, q=None):
    "Make `p` listy and the same length as `q`."
    if p is None: p=[]
    elif isinstance(p, str):          p = [p]
    elif not isinstance(p, Iterable): p = [p]
    #Rank 0 tensors in PyTorch are Iterable but don't have a length.
    else:
        try: a = len(p)
        except: p = [p]
    n = q if type(q)==int else len(p) if q is None else len(q)
    if len(p)==1: p = p * n
    assert len(p)==n, f'List len mismatch ({len(p)} vs {n})'
    return list(p)

# %%
def setify1(o): return o if isinstance(o, set) else set(listify(o))

# %%
setify1('aa') == {'aa'}
# Out:
# True

# %%
setify(['aa',1]) == {'aa',1}
# Out:
# True

# %%
setify1(None) == set()
# Out:
# True

# %%
setify1(1) == {1}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-f5cdf1e731c0> in <module>
# ----> 1 setify1(1) == {1}
#
# <ipython-input-128-9c76fd4fdf15> in setify1(o)
# ----> 1 def setify1(o): return o if isinstance(o, set) else set(listify(o))
#
# <ipython-input-126-e8dc2172b926> in listify(p, q)
#       3     if p is None: p=[]
#       4     elif isinstance(p, str):          p = [p]
# ----> 5     elif not isinstance(p, Iterable): p = [p]
#       6     #Rank 0 tensors in PyTorch are Iterable but don't have a length.
#       7     else:
#
# NameError: name 'Iterable' is not defined

# %%
setify({1}), {1}
# Out:
# ({1}, {1})
